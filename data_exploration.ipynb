# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# 'c:\\Users\\hbori\\Documents\\Itau_env\\Itau-group2'

# %%
# Read a Parquet file into a DataFrame
df = pd.read_parquet('./data/processed/validate_pairs_ref_10k.parquet')

# %%
df.head()
# Out:
#   fraudulent_name    real_name  label
# 0      meĝaĉriŧic   megacritic    1.0
# 1         thedodo    queveohoy    0.0
# 2       alrnundoz      almundo    1.0
# 3          nijobs      topjobs    0.0
# 4     trhonethrow  thronethrow    1.0

# %%
# read in the validation npz embeddings
data = np.load('./data/embeddings/siglip_glyphs/image_embeddings_validate.npz')

# %%
print(data.files)
# Out:
# ['globekart.png', '_dailybloes.png', 'tecnonadroidrc.png', 'ubzzsenegaŀ.png', 'onlineaccess1.png', 'today.png', 'basci-indusťires.png', 'tzuyentranhtuanam.png', 'çħerẏls.png', 'iņștallatron.png', 'do-uguohu.png', 'oldŝc-hõolhack.png', 'puẕzleclico.png', 'jefferson.png', '7ebisîdā.png', 'znogf.png', 'congomamkli.png', 'porngladi-atorn.png', 'ŗĉipdonor.png', 'mywxtyps.png', 'cbnanashi.png', '7asãl.png', 'sliɱmingworld.png', '99webtools.png', 'flmncz.png', 'omni-cash.png', 'yiankutku.png', 'edtguide.png', 'dooŕtodoororgaňics.png', 'bankotsär.png', '4ƒuŉmovíes.png', 'vendąnythinġ.png', 'rayifleih.png', 'bionluķ.png', 'swicapoint.png', 'wishmalantiheya.png', 'dcreälmʂg.png', 'chinaaauto.png', 'uhcaar.png', 'dragonseao.png', 'lmcʈrućk.png', 'ļashmgvie.png', 'peeco.png', 'luzhgu.png', 'esdiario.png', 'âdswiķĭ.png', 'prøfįtfm.png', 'ňėdiyor.png', 'rijq.png', 'chřȑonẏcle.png', 'cśhlpy.png', 'szgșwŀjġ.png', 'üėņ.png', 'almõmenttov.png', 'gb-sŋiffer.png', 'lnwcostholldays.png', 'danóňe.png', 'percent-chanwe.png', 'webstarŧs.png', 'sûɍfsitmoney.png', 'grinƌlv.png', 'cr-eatiivitem.png', 'wãz_yef.png', 'authoritywebs1tteincomĕ.png', 'skhıttz.png', 'youe7l.png', 'memecats.png', 'schoolwebpagesz.png', 'curȗin.png', 'al1yun-inċ.png', 'ilagriſith.png', 'hâfêļe.png', 'fdll24.png', 'cursbnr.png', 'opetnhefƒile.png', 'dob-ledwtch.png', 'freeclutr.png', '7c124.png', 'bluebuſfalo.png', 'páttaẏa-addicts.png', 'ťeȕfĕl.png', 'eyebuydirect.png', 'existenŧialcŏmics.png', 'boomƥzoxy.png', 'fllightcentre.png', 'inföʈoƥ.png', 'timesclub.png', 'qualitylegion.png', 'microsoft-news.png', 'mavicianwiz.png', 'ndxeps.png', 'bigreśõűrce.png', 'cre4tiveįtem.png', 'õ4š.png', 'etdknixj.png', 'mêdgadgēt.png', 'qoòch.png', 'omanaiɍb.png', 'caɱșonĺine.png', '3p3f.png', '528rbbs.png', 'metarvnmtwokr.png', 'onlydomains.png', 'utvonâlțervf.png', 'mfa.png', 'atkearŋey.png', 'bûzznoöķ.png', 'ƌk.png', 'fost.png', 'lieferlheŀd.png', '7ōlɱ.png', 'koreaþ4w.png', 'themgirl-who-ate-e_verything.png', 'p-őstcodeioterij.png', 'iyue-wa_ň.png', 't40mee.png', 'dadeschhmolsc.png', 'everɋŝaving.png', 'han-shintigers.png', 'viaſačilj.png', 'rɍd.png', 'asemooni.png', 'splitm-edya.png', 'sibcycline.png', 'wbbur.png', 'imnuţo30d.png', 'duɱbinģoſage.png', 'howqfsca.png', 'seventorrenus.png', '126_x2.png', 'sun0tibiero.png', 'jntufastvpdafes.png', '59uhr.png', 'ԛẓ.png', 'ft-chas.png', 'tamiłĵaffna.png', 'browneyedaker.png', 'k4limeraelŀada.png', 'zoneałaŕɱ.png', 'spoƀdys.png', 'smóozëd.png', 'ppointmmeijin.png', 'woddeweiŀai.png', 'affiliat-b.png', '4aebaup.png', 'ɱax_ïma.png', 'bitĕthisforɱe.png', 'lambstep3.png', 'saƌnboxie.png', '1960bet.png', 'dirêcțsalesq.png', 'jorunil-newst.png', 'bitwoïnker.png', 'esșîrag.png', 'rentɱystay.png', 'b_anpegîo.png', 'osu.png', 'turolshmaritime.png', 'hi-bain.png', 'huoche.png', 'arduiņo.png', 'neotɍaveĺeȓ.png', 'deńtistryiq.png', 'telly3nny.png', 'pàntolē.png', 'avoncosmetics.png', 'goodrețuřȑŋs.png', 'ēȓoshare.png', 'inķbnúny.png', 'crąsk3inn.png', 'securustech.png', 'shirnkthewebjh.png', 'heriss.png', 'kaoðeotu.png', 'xda-developers.png', 'camar-aabo.png', 'weaselzippers.png', 'iav-tnb.png', 'hamku.png', 'mfile5_.png', 'rusrandv.png', 'ärabñëws.png', 'guardianiv.png', 'ƒlightrising.png', 'ðets-kojîma.png', 'ocks.png', '4ẓz0q.png', 'advanceedmaccleaner.png', 'ynnigo.png', 'rrrchostingf.png', 'ca-centresŧ.png', 'olàsti-fora.png', 'vĝtiɱe.png', 'pgeverẋday.png', 'inƒineonƒ.png', 'joh.png', 'stateŝmànjournal.png', 'baćktrack-liñux.png', 'whatdigïtalcamëra.png', 'digiťalconcerthaĺl.png', 'țĩẋuz.png', 'sïtešĕrver.png', 'iosrjournals.png', '52g_-uag-ua.png', 'societẏ6.png', 'alyudlq.png', 'autik×y.png', 'psychic-ȓeadings-for-_free.png', 'memořȑĩaļsolutions.png', 'fãrhañe.png', 'hanshintigers.png', 'dramqãt.png', 'chēgguc.png', 'bergfexx.png', 'sur8upgayporn.png', 'tester-kopea.png', 'useerreport.png', 'serieŝ4watch.png', 'cfn ...

# %%
data_names = [name.split(".")[0] for name in data.files]
df_real_names = pd.unique(df[['real_name']].values.ravel('K')).tolist()
df_fraud_names = pd.unique(df[['fraudulent_name']].values.ravel('K')).tolist()

# %%
# check if each pair of real name & fraudulent name is in the data names
matches = [(real, fraud) for real, fraud in zip(df_real_names, df_fraud_names) if real in data_names and fraud in data_names]

# %%
len(matches)
# Out:
# 2162
